# %% [markdown]
# # Aplicativos windows store atualizado em 16 out 2021

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('windows_store.csv')
df.head()
# Out:
#                              Name Price  \
# 0                WhatsApp Desktop  Free
# 1                Telegram Desktop  Free
# 2  Amazon Prime Video for Windows  Free
# 3                       Instagram  Free
# 4                   Spotify Music  Free
#
#                                          Description  \
# 0  With WhatsApp on the desktop, you can seamless...
# 1  Pure instant messaging — simple, fast, secure,...
# 2  Watch movies and TV shows recommended for you,...
# 3  Bringing you closer to the people and things y...
# 4  Love music? Play your favorite songs and album...
#
#                                 Publisher Date of Release       Category  \
# 0                           WhatsApp Inc.      01-02-2017         Social
# 1                  Telegram Messenger LLP      03-04-2017         Social
# 2  Amazon Development Centre (London) Ltd      24-02-2020  Entertainment
# 3                               Instagram      26-02-2016         Social
# 4                              Spotify AB      26-05-2017          Music
#
#         Size          Age Rating  \
# 0  379.39 MB   For ages 3 and up
# 1     103 MB  For ages 18 and up
# 2   39.86 MB  For ages 12 and up
# 3    4.59 MB  For ages 12 and up
# 4  182.41 MB  For ages 12 and up
#
#                                            Languages
# 0                              English(UnitedStates)
# 1                              English(UnitedStates)
# 2  English(UnitedStates)   English(UnitedKingdom)...
# 3                              English(UnitedStates)
# 4  English(UnitedStates)   العربية(المملكةالعربية...

# %% [markdown]
# # Quais são os tópicos da tabela?

# %%
for i in df.columns:
    print(i)
# Out:
# Name
# Price
# Description
# Publisher
# Date of Release
# Category
# Size
# Age Rating
# Languages

# %% [markdown]
# # Quais os 10 primeiros aplicativos da Windows Store?

# %%
df = df.dropna(how="any", axis= 0)
df['Date of Release'] = pd.to_datetime(df['Date of Release'], errors="coerce")
primeiros_apps = df.sort_values('Date of Release',ascending=True)
primeiros_apps['Date of Release'] = df['Date of Release'].dt.strftime('%d/%m/%Y')
primeiros_apps = primeiros_apps[['Name','Category','Date of Release']]
primeiros_apps = primeiros_apps.head(n=10)
primeiros_apps.index = range(1,11)
primeiros_apps
# Out:
#                              Name                        Category  \
# 1                    Paint 4 Kids                   Family & kids
# 2                           freda  Books & reference  >  E-reader
# 3                         Netflix                   Entertainment
# 4   Microsoft Ultimate Word Games                    Card & board
# 5                          freda+  Books & reference  >  E-reader
# 6                    TuneIn Radio                           Music
# 7                       AV Remote                           Music
# 8                   Survivalcraft              Action & adventure
# 9              The Economic Times         News & weather  >  News
# 10             The Times of India         News & weather  >  News
#
#    Date of Release
# 1       13/10/2010
# 2       15/10/2010
# 3       18/10/2010
# 4       04/01/2011
# 5       21/01/2011
# 6       23/02/2011
# 7       20/10/2011
# 8       16/11/2011
# 9       28/12/2011
# 10      28/12/2011

# %% [markdown]
# # Quais os 10 últimos aplicativos da Windows Store?

# %%
ultimos_apps = df.sort_values('Date of Release',ascending=False)
ultimos_apps = ultimos_apps[['Name','Category','Date of Release']]
ultimos_apps = ultimos_apps.head(n=10)
ultimos_apps.index = range(1,11)
ultimos_apps
# Out:
#                                                  Name            Category  \
# 1     Pop It Fidget 3D - Relaxing Toys Trading Master       Entertainment
# 2   PDF Converter Suite - PDF to Word(Docx), XLS, ...        Productivity
# 3                         Bubble Ouch: Pop it Fidgets          Platformer
# 4              Whispered Secrets: Ripple of the Heart  Action & adventure
# 5   Finding Yeti — Find the mystery frost monster:...  Action & adventure
# 6                          Butterfly (for Windows 10)  Action & adventure
# 7                        Butterfly 2 (for Windows 10)  Action & adventure
# 8              Castle of no Escape 2 (for Windows 10)  Action & adventure
# 9                           50 Years (for Windows 10)        Card & board
# 10                            Cooking Frenzy FastFood  Action & adventure
#
#    Date of Release
# 1       2021-12-08
# 2       2021-12-08
# 3       2021-12-07
# 4       2021-12-06
# 5       2021-12-05
# 6       2021-12-05
# 7       2021-12-05
# 8       2021-12-05
# 9       2021-12-05
# 10      2021-12-03

# %% [markdown]
# # Qual a porcentagem de categorias na Windows Store?

# %%
categories = df.groupby(['Category']).count()
categories = categories[['Name']]
categories = categories.rename(columns={'Name':'Count'})
categories['Percentage'] = (categories['Count']/ categories['Count'].sum())*100
others = categories['Percentage']
categories = categories.sort_values('Percentage', ascending=False)
categories = categories.reset_index()
categories.index = categories.index + 1
categories
# Out:
#                                   Category  Count  Percentage
# 1                       Action & adventure    686   19.082058
# 2                        Utilities & tools    328    9.123783
# 3                             Productivity    287    7.983310
# 4                            Photo & video    256    7.121001
# 5               Personalization  >  Themes    207    5.757997
# ..                                     ...    ...         ...
# 83         Business  >  Project management      1    0.027816
# 84                                   Tools      1    0.027816
# 85           Lifestyle  >  Style & fashion      1    0.027816
# 86                        Business  >  CRM      1    0.027816
# 87  Personal finance  >  Budgeting & taxes      1    0.027816
#
# [87 rows x 3 columns]

# %% [markdown]
# # Maiores quantidade de aplicativos por Categorias

# %%
categories = categories[categories['Percentage']>=3]
categories
# Out:
#                      Category  Count  Percentage
# 1          Action & adventure    686   19.082058
# 2           Utilities & tools    328    9.123783
# 3                Productivity    287    7.983310
# 4               Photo & video    256    7.121001
# 5  Personalization  >  Themes    207    5.757997
# 6                  Simulation    164    4.561892
# 7                Card & board    108    3.004172
# 8               Entertainment    108    3.004172

# %%
y = categories['Category']
x = categories['Percentage']
plt.figure(figsize = (16,8))
sns.barplot(x, y, orient = "h", palette = "terrain")
plt.ylabel('Categorias')             
plt.xlabel("\nPercentual de aplicativos (%)")
plt.title('\nCategorias que mais aparecem na Store\n')
plt.show()
# Out:
# /home/roger/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
